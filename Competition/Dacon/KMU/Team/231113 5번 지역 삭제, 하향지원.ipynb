# %% [markdown]
# # Connect to google account

# %%
# 구글 드라이브 연결
from google.colab import drive
drive.mount("/content/data")
# Out:
# Mounted at /content/data

# %%
# !pip install category_encoders
# Out:
# Collecting category_encoders
#   Downloading category_encoders-2.6.3-py2.py3-none-any.whl (81 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 81.9/81.9 kB 1.4 MB/s eta 0:00:00
# Requirement already satisfied: numpy>=1.14.0 in /usr/local/lib/python3.10/dist-packages (from category_encoders) (1.23.5)
# Requirement already satisfied: scikit-learn>=0.20.0 in /usr/local/lib/python3.10/dist-packages (from category_encoders) (1.2.2)
# Requirement already satisfied: scipy>=1.0.0 in /usr/local/lib/python3.10/dist-packages (from category_encoders) (1.11.3)
# Requirement already satisfied: statsmodels>=0.9.0 in /usr/local/lib/python3.10/dist-packages (from category_encoders) (0.14.0)
# Requirement already satisfied: pandas>=1.0.5 in /usr/local/lib/python3.10/dist-packages (from category_encoders) (1.5.3)
# Requirement already satisfied: patsy>=0.5.1 in /usr/local/lib/python3.10/dist-packages (from category_encoders) (0.5.3)
# Requirement already satisfied: python-dateutil>=2.8.1 in /usr/local/lib/python3.10/dist-packages (from pandas>=1.0.5->category_encoders) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas>=1.0.5->category_encoders) (2023.3.post1)
# Requirement already satisfied: six in /usr/local/lib/python3.10/dist-packages (from patsy>=0.5.1->category_encoders) (1.16.0)
# Requirement already satisfied: joblib>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from scikit-learn>=0.20.0->category_encoders) (1.3.2)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from scikit-learn>=0.20.0->category_encoders) (3.2.0)
# Requirement already satisfied: packaging>=21.3 in /usr/local/lib/python3.10/dist-packages (from statsmodels>=0.9.0->category_encoders) (23.2)
# Installing collected packages: category_encoders
# Successfully installed category_encoders-2.6.3

# %%
# 모듈 Import
import random
import numpy as np # 행렬 계산에 사용하는 모듈
import pandas as pd # 데이터 처리와 분석을 위한 모듈
import matplotlib.pyplot as plt # 데이터 시각화를 위한 모듈. 2D, 3D 그릴 때 사용
import seaborn as sns # 데이터 시각화를 위한 모듈. 두 데이터의 관계를 볼때 사용

import category_encoders as ce

from datetime import datetime, timedelta
from tqdm.auto import tqdm

import warnings
# FutureWarning 경고를 무시하도록 설정
warnings.simplefilter(action='ignore', category=FutureWarning)

# %%
# 딕셔너리를 간편하게 사용하는 것을 도와준다. 모델 class 처럼 사용 가능
# dot을 이용해 객체를 불러 사용. JSON 다룰때 유용.
import easydict
args = easydict.EasyDict()

# path
args.default_path = "/content/data/MyDrive/dev/deep learning/국민대 ai 경진대회 데이콘/ori 데이터/" # 메인 경로
args.apply_train_path = args.default_path + "apply_train.csv" # train 데이터 경로
args.company_path = args.default_path + "company.csv"
args.recruitment_path = args.default_path + "recruitment.csv"
args.resume_certificate_path = args.default_path + "resume_certificate.csv"
args.resume_education_path = args.default_path + "resume_education.csv"
args.resume_language_path = args.default_path + "resume_language.csv"
args.resume_path = args.default_path + "resume.csv"

args.default_submission_path = args.default_path + "sample_submission.csv" # 예측결과(제출파일) 경로

# 데이터 분석을 위한 변수들
# # 난수 생성 제어 => 같은 코드를 실행해도 동일한 결과를 얻기 위해서 설정
# 데이터 분할 및 모델 초기화 때 유용.
args.random_state = 42
args.results = [] # 결과 저장 리스트

# %%
args.submission_path = args.default_path + "result/submission_20231108.csv" # 결과 저장 파일
args.save_results = args.default_path+"result/model_results_20231108.json" # 결과 저장 json

# %%
def recall5(answer_df, submission_df):

    primary_col = answer_df.columns[0]
    secondary_col = answer_df.columns[1]

    # submission의 예측이 각각 5개인지 확인
    prediction_counts = submission_df.groupby(primary_col).size()
    if not all(prediction_counts == 5):
        raise ValueError(f"Each {primary_col} should have exactly 5 {secondary_col} predictions.")


    # submission의 예측된 값들에 null값이 있는지 확인
    if submission_df[secondary_col].isnull().any():
        raise ValueError(f"Predicted {secondary_col} contains NULL values.")

    # 예측값에 중복이 있는지 확인
    duplicated_preds = submission_df.groupby(primary_col).apply(lambda x: x[secondary_col].duplicated().any())
    if duplicated_preds.any():
        raise ValueError(f"Predicted {secondary_col} contains duplicates for some {primary_col}.")


    # Filter the submission dataframe based on the primary_col present in the answer dataframe
    # primary_col 즉 resume_seq가 양측에 있는지 확인 후 남김
    submission_df = submission_df[submission_df[primary_col].isin(answer_df[primary_col])]

    # For each primary_col, get the top 5 predicted secondary_col values
    #
    top_5_preds = submission_df.groupby(primary_col).apply(lambda x: x[secondary_col].head(5).tolist()).to_dict()

    # Convert the answer_df to a dictionary for easier lookup
    true_dict = answer_df.groupby(primary_col).apply(lambda x: x[secondary_col].tolist()).to_dict()


    individual_recalls = []
    for key, val in true_dict.items():
        if key in top_5_preds:
            correct_matches = len(set(true_dict[key]) & set(top_5_preds[key]))
            individual_recall = correct_matches / min(len(val), 5) # 공정한 평가를 가능하게 위하여 분모(k)를 'min(len(val), 5)' 로 설정함
            individual_recalls.append(individual_recall)


    #recall = np.mean(individual_recalls)
    recall = max(individual_recalls)
    return recall

# %% [markdown]
# # File Load

# %%
apply_train_df = pd.read_csv(args.apply_train_path) # apply_train -> DataFrame화
company_df = pd.read_csv(args.company_path) # company -> DataFrame화
recruitment_df = pd.read_csv(args.recruitment_path) # recruitment -> DataFrame화
resume_certificate_df = pd.read_csv(args.resume_certificate_path) # resume_certificate -> DataFreame화
resume_education_df = pd.read_csv(args.resume_education_path) # resume_education -> DataFrame화
resume_language_df = pd.read_csv(args.resume_language_path) # resume_language -> DataFrame화
resume_df = pd.read_csv(args.resume_path) # resume -> DataFrame화
submission_df = pd.read_csv(args.default_submission_path)

# %%
apply_train = apply_train_df.copy()
company = company_df.copy()
recruitment = recruitment_df.copy()
resume_certificate = resume_certificate_df.copy()
resume_education = resume_education_df.copy()
resume_language = resume_language_df.copy()
resume = resume_df.copy()

# %% [markdown]
# ### merged_recruitment 생성

# %%
# recruitment, company 정렬(recruitment_seq 기준)
company = company.sort_values(by = "recruitment_seq")
recruitment = recruitment.sort_values(by = "recruitment_seq")

# %%
# merged_recruitment = recruitment, company merge
merged_recruitment = pd.merge(recruitment, company, on='recruitment_seq', how='left')
merged_recruitment
# Out:
#      recruitment_seq  address_seq1  address_seq2  address_seq3  career_end  \
# 0             R00001           5.0           NaN           NaN           0
# 1             R00002           3.0           NaN           NaN           0
# 2             R00003           3.0           NaN           NaN           0
# 3             R00004           3.0           NaN           NaN           0
# 4             R00005           3.0           NaN           NaN           0
# ...              ...           ...           ...           ...         ...
# 6690          R06691           3.0           NaN           NaN           0
# 6691          R06692           3.0           NaN           NaN           0
# 6692          R06693           5.0           NaN           NaN           0
# 6693          R06694           3.0           NaN           NaN           0
# 6694          R06695           3.0           NaN           NaN           0
#
#       career_start                   check_box_keyword  education  major_task  \
# 0                0  2101;2108;2201;2204;2205;2707;2810          2           2
# 1                0                      2507;2703;2707          3           2
# 2                0                 2101;2108;2201;2707          3           2
# 3                0                           2507;2707          3           2
# 4                0                           2507;2707          3           2
# ...            ...                                 ...        ...         ...
# 6690             0                      2501;2507;2707          3           2
# 6691             0                           2201;2507          3           2
# 6692             0                           2102;2707          4           2
# 6693             0  2101;2108;2109;2110;2201;2203;2707          4           2
# 6694             0                           2507;2707          3           2
#
#       qualifications text_keyword  company_type_seq  supply_kind  employee
# 0                  1          NaN               5.0        201.0     631.0
# 1                  1          NaN               2.0        201.0     160.0
# 2                  2          NaN               NaN          NaN       NaN
# 3                  1          NaN               2.0        402.0     500.0
# 4                  1          NaN               NaN          NaN       NaN
# ...              ...          ...               ...          ...       ...
# 6690               1          NaN               NaN          NaN       NaN
# 6691               2          NaN               4.0        402.0     150.0
# 6692               1          NaN               NaN          NaN       NaN
# 6693               1          NaN               NaN          NaN       NaN
# 6694               1          NaN               NaN          NaN       NaN
#
# [6695 rows x 14 columns]

# %%
#5번 지역 회사의 수 / 5번 지역에 지원을 하나라도 한 사람의 목록을 얻기(merge total에서 address_seq1가 5인 행 모으기 -> 이때 나타난 모든 resume seq 값을 리스트로 생성 -> merge total에서 그 리스트의 resume seq가 포함된 행들을 전부 보이기)
#-> merge total에서 그 사람들의 행을 모아보기 -> 그 사람들이 이력서 전부를 5번 지역에 썼는지 아니 분산해서 썼는지 check
#이게 바로 설계?

# %%
selected_rows = merged_recruitment[merged_recruitment['address_seq1'] == 5.0]
selected_rows
# Out:
#      recruitment_seq  address_seq1  address_seq2  address_seq3  career_end  \
# 0             R00001           5.0           NaN           NaN           0
# 86            R00087           5.0           NaN           NaN           0
# 178           R00179           5.0           NaN           NaN           0
# 201           R00202           5.0           NaN           NaN           0
# 209           R00210           5.0           NaN           NaN           0
# ...              ...           ...           ...           ...         ...
# 6493          R06494           5.0           NaN           NaN           0
# 6579          R06580           5.0           NaN           NaN           0
# 6620          R06621           5.0           NaN           NaN           0
# 6661          R06662           5.0           NaN           NaN           0
# 6692          R06693           5.0           NaN           NaN           0
#
#       career_start                   check_box_keyword  education  major_task  \
# 0                0  2101;2108;2201;2204;2205;2707;2810          2           2
# 86               0                           2507;2707          3           2
# 178              0                 2201;2204;2299;2914          3           2
# 201              0                           2507;2707          3           2
# 209              0                 2201;2204;2205;2707          2           2
# ...            ...                                 ...        ...         ...
# 6493             0                 2201;2204;2205;2707          4           2
# 6579             0                 2201;2204;2205;2707          2           2
# 6620             0  2101;2108;2201;2204;2205;2507;2707          3           2
# 6661             0                 2201;2204;2205;2707          2           2
# 6692             0                           2102;2707          4           2
#
#       qualifications      text_keyword  company_type_seq  supply_kind  \
# 0                  1               NaN               5.0        201.0
# 86                 1               NaN               NaN          NaN
# 178                2               NaN               7.0        409.0
# 201                1               NaN               NaN          NaN
# 209                2               NaN               NaN          NaN
# ...              ...               ...               ...          ...
# 6493               2               NaN               NaN          NaN
# 6579               2  영업;매장관리;영업부;영업관리               NaN          NaN
# 6620               2               NaN               NaN          NaN
# 6661               2               NaN               NaN          NaN
# 6692               1               NaN               NaN          NaN
#
#       employee
# 0        631.0
# 86         NaN
# 178       18.0
# 201        NaN
# 209        NaN
# ...        ...
# 6493       NaN
# 6579       NaN
# 6620       NaN
# 6661       NaN
# 6692       NaN
#
# [174 rows x 14 columns]

# %% [markdown]
# ### merged_resume 생성

# %%
# resume 정렬 (resume_seq 기준)
resume = resume.sort_values(by='resume_seq')

# %%
# resume_certificate 정렬 (resume_seq 기준)
resume_certificate = resume_certificate.sort_values(by='resume_seq')
# certificate_contents에 결측값이 존재하는 행 제거
resume_certificate = resume_certificate.dropna(subset=['certificate_contents'])
# 이력서번호(resume_seq)기준으로 groupby
# 이력서번호(resume_seq)의 해당하는 자격증들을 세미콜론(;)으로 join해서 적용(apply)
resume_certificate = resume_certificate.groupby('resume_seq')['certificate_contents'].apply(';'.join).reset_index()

# %%
# resume_education 정렬 (resume_seq 기준)
resume_education = resume_education.sort_values(by='resume_seq')

# %%
# resume_language 정렬 (resume_seq 기준)
resume_language = resume_language.sort_values(by='resume_seq')
resume_language = resume_language.drop_duplicates(subset='resume_seq')

# %%
# merged_resume = resume, resume_certificate, resume_education, resume_language
merged_resume = pd.merge(resume, resume_certificate, on='resume_seq', how='left')
merged_resume = pd.merge(merged_resume, resume_education, on='resume_seq', how='left')
merged_resume = pd.merge(merged_resume, resume_language, on='resume_seq', how='left')
merged_resume
# Out:
#      resume_seq    reg_date updated_date  degree  graduate_date  hope_salary  \
# 0        U00001  2019-12-27   2020-02-01       4           2009         1500
# 1        U00002  2020-04-24   2020-04-29       4           2005            0
# 2        U00003  2018-02-14   2020-07-08       4           2004            0
# 3        U00004  2017-10-26   2020-04-27       4           2011            0
# 4        U00005  2020-03-18   2020-04-08       4           2011            0
# ...         ...         ...          ...     ...            ...          ...
# 8477     U08478  2020-02-05   2020-03-31       4           2003            0
# 8478     U08479  2016-02-17   2020-07-15       3              0         2500
# 8479     U08480  2019-11-13   2020-06-24       4              0            0
# 8480     U08481  2020-07-09   2020-11-23       4           2015            0
# 8481     U08482  2020-11-29   2020-11-29       4              0            0
#
#       last_salary                    text_keyword job_code_seq1 job_code_seq2  \
# 0            1500                            디자이너   재료·화학·섬유·의복           NaN
# 1               0                            디자이너   재료·화학·섬유·의복           NaN
# 2               0                   남성복디자이너;TD캐주얼   재료·화학·섬유·의복           NaN
# 3               0                       상품기획;영업기획   재료·화학·섬유·의복           NaN
# 4               0                인사;총무;경영;MD;상품기획   재료·화학·섬유·의복           NaN
# ...           ...                             ...           ...           ...
# 8477         2700                            상품기획   재료·화학·섬유·의복           NaN
# 8478         2300                            디자이너   재료·화학·섬유·의복           NaN
# 8479            0  VMD;텍스타일디자인;섬유디자인;니트디자인;여성복디자인           디자인           NaN
# 8480         2700                 상품기획;머천다이저;기획MD   재료·화학·섬유·의복           NaN
# 8481            0     상품기획;영업MD;머천다이저;기획MD;마케팅;PR   재료·화학·섬유·의복           NaN
#
#       ... univ_type_seq2  univ_transfer univ_location       univ_major  \
# 0     ...              5              0            17              NaN
# 1     ...              5              0             3              NaN
# 2     ...              5              0            17              NaN
# 3     ...              5              0             5              NaN
# 4     ...              0              0             0              NaN
# ...   ...            ...            ...           ...              ...
# 8477  ...              5              0             5              NaN
# 8478  ...              6              0             3              가정과
# 8479  ...              5              0            10  미술대학섬유패션코디네이션학과
# 8480  ...              5              0             5              NaN
# 8481  ...              0              0             0              NaN
#
#       univ_sub_major univ_major_type univ_score language  exam_name   score
# 0                NaN               9       20.0      NaN        NaN     NaN
# 1                NaN               8       90.0      NaN        NaN     NaN
# 2                NaN               4       90.0      NaN        NaN     NaN
# 3                NaN               3       70.0      2.0       11.0  661.62
# 4                NaN              10       50.0      2.0        4.0  873.74
# ...              ...             ...        ...      ...        ...     ...
# 8477             NaN              19        0.0      NaN        NaN     NaN
# 8478             NaN               9        0.0      NaN        NaN     NaN
# 8479             NaN               9       80.0      NaN        NaN     NaN
# 8480             NaN               9       60.0      NaN        NaN     NaN
# 8481             NaN               9       80.0      2.0       11.0  600.00
#
# [8482 rows x 30 columns]

# %% [markdown]
# ### merged_total 생성

# %%
_merged_total = pd.merge(apply_train, merged_recruitment, left_on='recruitment_seq', right_on='recruitment_seq', how='left')
_merged_total = pd.merge(_merged_total, merged_resume, left_on='resume_seq', right_on='resume_seq', how='left')
merged_total = _merged_total
merged_total
# Out:
#       resume_seq recruitment_seq  address_seq1  address_seq2  address_seq3  \
# 0         U05833          R03838           3.0           NaN           NaN
# 1         U06456          R02144           3.0           NaN           NaN
# 2         U07807          R01877           3.0           NaN           NaN
# 3         U04842          R02463           3.0           NaN           NaN
# 4         U08336          R00112           3.0           NaN           NaN
# ...          ...             ...           ...           ...           ...
# 57941     U02270          R03430           3.0           NaN           NaN
# 57942     U02640          R04987           3.0           1.0           NaN
# 57943     U08238          R01342           3.0           NaN           NaN
# 57944     U01296          R06363           3.0           NaN           NaN
# 57945     U05748          R03090           3.0           NaN           NaN
#
#        career_end  career_start    check_box_keyword  education  major_task  \
# 0               0             0  2110;2203;2204;2299          3           2
# 1               0             0       2204;2507;2707          3           2
# 2               0             0            2507;2707          3           2
# 3               0             0            2507;2707          4           2
# 4               0             0            2507;2707          3           8
# ...           ...           ...                  ...        ...         ...
# 57941           0             0            2507;2707          3           2
# 57942           0             0            2707;2507          3           2
# 57943           0             0  2201;2204;2205;2707          2           2
# 57944           0             0  2201;2204;2205;2707          3           2
# 57945           0             0            2102;2707          3           2
#
#        ...  univ_type_seq2 univ_transfer  univ_location  univ_major  \
# 0      ...               5             0              3         NaN
# 1      ...               5             0             10      국어국문학과
# 2      ...               5             0             15         NaN
# 3      ...               5             0              3         NaN
# 4      ...               5             0             17         NaN
# ...    ...             ...           ...            ...         ...
# 57941  ...              10             0              5    패션디자인과종합
# 57942  ...               5             0              3        조소학과
# 57943  ...               5             0             12         NaN
# 57944  ...               5             0             18      의상디자인학
# 57945  ...               5             0              3       금속공학과
#
#        univ_sub_major univ_major_type univ_score  language  exam_name  score
# 0                 NaN               3       60.0       NaN        NaN    NaN
# 1                 NaN               8       70.0       NaN        NaN    NaN
# 2                 NaN               4       80.0       NaN        NaN    NaN
# 3                 NaN               9       80.0       NaN        NaN    NaN
# 4                 NaN               9       70.0       NaN        NaN    NaN
# ...               ...             ...        ...       ...        ...    ...
# 57941             NaN               9        0.0       NaN        NaN    NaN
# 57942             NaN               9       70.0       NaN        NaN    NaN
# 57943             NaN               3       70.0       NaN        NaN    NaN
# 57944             NaN               9       80.0       NaN        NaN    NaN
# 57945             NaN              10       70.0       NaN        NaN    NaN
#
# [57946 rows x 44 columns]

# %%
merged_total.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 57946 entries, 0 to 57945
# Data columns (total 44 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   resume_seq             57946 non-null  object
#  1   recruitment_seq        57946 non-null  object
#  2   address_seq1           57940 non-null  float64
#  3   address_seq2           877 non-null    float64
#  4   address_seq3           73 non-null     float64
#  5   career_end             57946 non-null  int64
#  6   career_start           57946 non-null  int64
#  7   check_box_keyword      57946 non-null  object
#  8   education              57946 non-null  int64
#  9   major_task             57946 non-null  int64
#  10  qualifications         57946 non-null  int64
#  11  text_keyword_x         5609 non-null   object
#  12  company_type_seq       20036 non-null  float64
#  13  supply_kind            20036 non-null  float64
#  14  employee               20036 non-null  float64
#  15  reg_date               57946 non-null  object
#  16  updated_date           57946 non-null  object
#  17  degree                 57946 non-null  int64
#  18  graduate_date          57946 non-null  int64
#  19  hope_salary            57946 non-null  int64
#  20  last_salary            57946 non-null  int64
#  21  text_keyword_y         56744 non-null  object
#  22  job_code_seq1          57946 non-null  object
#  23  job_code_seq2          2937 non-null   object
#  24  job_code_seq3          1126 non-null   object
#  25  career_month           57946 non-null  int64
#  26  career_job_code        54557 non-null  object
#  27  certificate_contents   42235 non-null  object
#  28  hischool_type_seq      57946 non-null  int64
#  29  hischool_special_type  57946 non-null  object
#  30  hischool_nation        57946 non-null  object
#  31  hischool_gender        57946 non-null  object
#  32  hischool_location_seq  57946 non-null  int64
#  33  univ_type_seq1         57946 non-null  int64
#  34  univ_type_seq2         57946 non-null  int64
#  35  univ_transfer          57946 non-null  int64
#  36  univ_location          57946 non-null  int64
#  37  univ_major             12864 non-null  object
#  38  univ_sub_major         2641 non-null   object
#  39  univ_major_type        57946 non-null  int64
#  40  univ_score             57946 non-null  float64
#  41  language               5051 non-null   float64
#  42  exam_name              5051 non-null   float64
#  43  score                  5051 non-null   float64
# dtypes: float64(10), int64(17), object(17)
# memory usage: 19.9+ MB

# %%
#5번 지역에 지원한 사람들 확인하기

selected_rows2 = merged_total[merged_total['address_seq1'] == 5.0]
selected_rows2
# Out:
#       resume_seq recruitment_seq  address_seq1  address_seq2  address_seq3  \
# 63        U03564          R05168           5.0           NaN           NaN
# 89        U07824          R03993           5.0           NaN           NaN
# 98        U04187          R02491           5.0           NaN           NaN
# 132       U01321          R02214           5.0           NaN           NaN
# 175       U03939          R03992           5.0           NaN           NaN
# ...          ...             ...           ...           ...           ...
# 57783     U07890          R05546           5.0           NaN           NaN
# 57799     U02096          R01833           5.0           NaN           NaN
# 57816     U02122          R05076           5.0           NaN           NaN
# 57860     U03350          R02425           5.0           NaN           NaN
# 57898     U00368          R04748           5.0           NaN           NaN
#
#        career_end  career_start  \
# 63              0             0
# 89              0             0
# 98              0             0
# 132             0             0
# 175             0             0
# ...           ...           ...
# 57783           0             0
# 57799           0             0
# 57816           0             0
# 57860           0             0
# 57898           0             0
#
#                                        check_box_keyword  education  \
# 63     2101;2108;2109;2201;2203;2204;2205;2302;2303;2...          2
# 89                              2101;2201;2204;2205;2707          3
# 98                                        2204;2205;2707          3
# 132                                  2101;2108;2201;2707          4
# 175                   2101;2108;2201;2204;2205;2707;2810          2
# ...                                                  ...        ...
# 57783                                2101;2108;2201;2707          2
# 57799                           2101;2201;2204;2205;2707          3
# 57816                           2108;2507;2703;2707;2810          2
# 57860                      2101;2108;2201;2204;2205;2707          4
# 57898                           2108;2507;2703;2707;2810          2
#
#        major_task  ...  univ_type_seq2 univ_transfer  univ_location  \
# 63              2  ...               5             0              5
# 89              2  ...               5             0             11
# 98              2  ...               5             0              9
# 132             2  ...               5             0              3
# 175             2  ...               5             0              5
# ...           ...  ...             ...           ...            ...
# 57783           2  ...               5             0              3
# 57799           2  ...               5             0              3
# 57816           2  ...               5             0             15
# 57860           2  ...               5             0              3
# 57898           2  ...               5             0             17
#
#        univ_major  univ_sub_major univ_major_type univ_score  language  \
# 63            NaN             NaN               0       90.0       NaN
# 89            NaN             NaN              14       70.0       NaN
# 98         패션정보기획             NaN               9       80.0       NaN
# 132           NaN             NaN               9       80.0       NaN
# 175         태권도학과             NaN               9        0.0       NaN
# ...           ...             ...             ...        ...       ...
# 57783         NaN             NaN               5       90.0       NaN
# 57799         NaN             NaN               0       50.0       NaN
# 57816         NaN             NaN               4       20.0       NaN
# 57860         NaN             NaN              18       70.0       NaN
# 57898         NaN             NaN               3       70.0       NaN
#
#        exam_name  score
# 63           NaN    NaN
# 89           NaN    NaN
# 98           NaN    NaN
# 132          NaN    NaN
# 175          NaN    NaN
# ...          ...    ...
# 57783        NaN    NaN
# 57799        NaN    NaN
# 57816        NaN    NaN
# 57860        NaN    NaN
# 57898        NaN    NaN
#
# [1475 rows x 44 columns]

# %%
resume_seq_classes = selected_rows2['resume_seq'].unique()
resume_seq_classes
# Out:
# array(['U03564', 'U07824', 'U04187', ..., 'U02122', 'U03350', 'U00368'],
#       dtype=object)

# %%
selected_rows3 = merged_total[merged_total['resume_seq'].isin(resume_seq_classes)]
selected_rows3
# Out:
#       resume_seq recruitment_seq  address_seq1  address_seq2  address_seq3  \
# 6         U01045          R03428           3.0           NaN           NaN
# 9         U01917          R01028           3.0           NaN           NaN
# 13        U06130          R05490           3.0           NaN           NaN
# 19        U06687          R06278           3.0           NaN           NaN
# 21        U07934          R05481           3.0           NaN           NaN
# ...          ...             ...           ...           ...           ...
# 57926     U00501          R01445           3.0           NaN           NaN
# 57928     U07167          R00334           3.0           NaN           NaN
# 57934     U01018          R03237           3.0           NaN           NaN
# 57944     U01296          R06363           3.0           NaN           NaN
# 57945     U05748          R03090           3.0           NaN           NaN
#
#        career_end  career_start         check_box_keyword  education  \
# 6               0             0       2201;2204;2205;2707          4
# 9               0             0  2101;2201;2204;2205;2707          3
# 13              0             0            2507;2703;2707          3
# 19              0             0       2507;2707;2201;2204          3
# 21              0             0                      2707          2
# ...           ...           ...                       ...        ...
# 57926           0             0       2707;2507;2201;2204          3
# 57928           0             0       2201;2204;2205;2707          3
# 57934           0             0            2507;2707;2810          2
# 57944           0             0       2201;2204;2205;2707          3
# 57945           0             0                 2102;2707          3
#
#        major_task  ...  univ_type_seq2 univ_transfer  univ_location  \
# 6               2  ...               5             0              3
# 9               2  ...               5             0              3
# 13              2  ...               5             0             10
# 19              2  ...               7             0              3
# 21              2  ...               5             0              4
# ...           ...  ...             ...           ...            ...
# 57926           2  ...               5             0             14
# 57928           2  ...               5             0              7
# 57934           2  ...               6             0              3
# 57944           2  ...               5             0             18
# 57945           2  ...               5             0              3
#
#        univ_major  univ_sub_major univ_major_type univ_score  language  \
# 6             NaN             NaN               9       60.0       NaN
# 9             NaN             NaN               8       60.0       NaN
# 13            NaN             NaN               4       70.0       NaN
# 19            NaN             NaN               3       80.0       NaN
# 21          체육교육과          관광경역학과              17       70.0       NaN
# ...           ...             ...             ...        ...       ...
# 57926         NaN             NaN               4       70.0       NaN
# 57928         조경학             NaN              20       70.0       NaN
# 57934         NaN             NaN              19       70.0       2.0
# 57944      의상디자인학             NaN               9       80.0       NaN
# 57945       금속공학과             NaN              10       70.0       NaN
#
#        exam_name   score
# 6            NaN     NaN
# 9            NaN     NaN
# 13           NaN     NaN
# 19           NaN     NaN
# 21           NaN     NaN
# ...          ...     ...
# 57926        NaN     NaN
# 57928        NaN     NaN
# 57934        4.0  873.74
# 57944        NaN     NaN
# 57945        NaN     NaN
#
# [15177 rows x 44 columns]

# %% [markdown]
# # New_apply_train 조건 탐색

# %% [markdown]
# ## 조건 1. 5번 지역 삭제

# %%
selected_rows2 = merged_total[merged_total['address_seq1'] != 5.0]
selected_rows2
# Out:
#       resume_seq recruitment_seq  address_seq1  address_seq2  address_seq3  \
# 0         U05833          R03838           3.0           NaN           NaN
# 1         U06456          R02144           3.0           NaN           NaN
# 2         U07807          R01877           3.0           NaN           NaN
# 3         U04842          R02463           3.0           NaN           NaN
# 4         U08336          R00112           3.0           NaN           NaN
# ...          ...             ...           ...           ...           ...
# 57941     U02270          R03430           3.0           NaN           NaN
# 57942     U02640          R04987           3.0           1.0           NaN
# 57943     U08238          R01342           3.0           NaN           NaN
# 57944     U01296          R06363           3.0           NaN           NaN
# 57945     U05748          R03090           3.0           NaN           NaN
#
#        career_end  career_start    check_box_keyword  education  major_task  \
# 0               0             0  2110;2203;2204;2299          3           2
# 1               0             0       2204;2507;2707          3           2
# 2               0             0            2507;2707          3           2
# 3               0             0            2507;2707          4           2
# 4               0             0            2507;2707          3           8
# ...           ...           ...                  ...        ...         ...
# 57941           0             0            2507;2707          3           2
# 57942           0             0            2707;2507          3           2
# 57943           0             0  2201;2204;2205;2707          2           2
# 57944           0             0  2201;2204;2205;2707          3           2
# 57945           0             0            2102;2707          3           2
#
#        ...  univ_type_seq2 univ_transfer  univ_location  univ_major  \
# 0      ...               5             0              3         NaN
# 1      ...               5             0             10      국어국문학과
# 2      ...               5             0             15         NaN
# 3      ...               5             0              3         NaN
# 4      ...               5             0             17         NaN
# ...    ...             ...           ...            ...         ...
# 57941  ...              10             0              5    패션디자인과종합
# 57942  ...               5             0              3        조소학과
# 57943  ...               5             0             12         NaN
# 57944  ...               5             0             18      의상디자인학
# 57945  ...               5             0              3       금속공학과
#
#        univ_sub_major univ_major_type univ_score  language  exam_name  score
# 0                 NaN               3       60.0       NaN        NaN    NaN
# 1                 NaN               8       70.0       NaN        NaN    NaN
# 2                 NaN               4       80.0       NaN        NaN    NaN
# 3                 NaN               9       80.0       NaN        NaN    NaN
# 4                 NaN               9       70.0       NaN        NaN    NaN
# ...               ...             ...        ...       ...        ...    ...
# 57941             NaN               9        0.0       NaN        NaN    NaN
# 57942             NaN               9       70.0       NaN        NaN    NaN
# 57943             NaN               3       70.0       NaN        NaN    NaN
# 57944             NaN               9       80.0       NaN        NaN    NaN
# 57945             NaN              10       70.0       NaN        NaN    NaN
#
# [56471 rows x 44 columns]

# %% [markdown]
# ## 조건2. 하향지원 삭제

# %%
#merged_total.shape
# Out:
# (57946, 44)

# %%
#merged_total.groupby('education')['degree'].value_counts(ascending=False)
# Out:
# education  degree
# 2          4         12633
#            3          1021
#            5           525
#            2           516
#            6            17
# 3          4         20912
#            3          1602
#            5           844
#            2           727
#            6            19
# 4          4         16914
#            3           913
#            5           832
#            2           445
#            6            15
# 6          4             9
#            3             1
#            5             1
# Name: degree, dtype: int64

# %%
#merged_total.groupby('degree')['education'].value_counts(ascending=False)
# Out:
# degree  education
# 2       3              727
#         2              516
#         4              445
# 3       3             1602
#         2             1021
#         4              913
#         6                1
# 4       3            20912
#         4            16914
#         2            12633
#         6                9
# 5       3              844
#         4              832
#         2              525
#         6                1
# 6       3               19
#         2               17
#         4               15
# Name: education, dtype: int64

# %%
#요구학위보다 최종학위가 높은 경우
#merged_total.loc[merged_total['education'] > merged_total['degree']].shape
# Out:
# (2096, 44)

# %%
#학위를 두 수준이나 낮춰서 하향지원한 경우
##요구학위 > 최종학위가 높은 경우를 먼저 drop 하기 때문에 요구학위 < 최종학위인 경우만 생각하면 됨
###degree = 6인 지원자는 반드시 하향지원을 할 수 밖에없어서 예외처리
#merged_total.loc[
    #(merged_total['degree'] != 6)
    #&
    #(merged_total['degree'] - merged_total['education'] == 2)
    #].shape
# Out:
# (13477, 44)

# %%
#def drop_degree(df):
    # 'education' 컬럼 값이 'degree' 컬럼 값보다 큰 조건을 만족하는 행 삭제
    #df.drop(df[df['education'] > df['degree']].index, inplace=True)
    #df.drop(df[(merged_total['degree'] != 6)
                #&
                #(merged_total['degree'] - merged_total['education'] == 2)
                #].index, inplace=True)
    #return df

# %% [markdown]
# #New_apply_train 생성 및 검증

# %%
new_merged_total = merged_total.copy()

# %%
new_merged_total.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 57946 entries, 0 to 57945
# Data columns (total 44 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   resume_seq             57946 non-null  object
#  1   recruitment_seq        57946 non-null  object
#  2   address_seq1           57940 non-null  float64
#  3   address_seq2           877 non-null    float64
#  4   address_seq3           73 non-null     float64
#  5   career_end             57946 non-null  int64
#  6   career_start           57946 non-null  int64
#  7   check_box_keyword      57946 non-null  object
#  8   education              57946 non-null  int64
#  9   major_task             57946 non-null  int64
#  10  qualifications         57946 non-null  int64
#  11  text_keyword_x         5609 non-null   object
#  12  company_type_seq       20036 non-null  float64
#  13  supply_kind            20036 non-null  float64
#  14  employee               20036 non-null  float64
#  15  reg_date               57946 non-null  object
#  16  updated_date           57946 non-null  object
#  17  degree                 57946 non-null  int64
#  18  graduate_date          57946 non-null  int64
#  19  hope_salary            57946 non-null  int64
#  20  last_salary            57946 non-null  int64
#  21  text_keyword_y         56744 non-null  object
#  22  job_code_seq1          57946 non-null  object
#  23  job_code_seq2          2937 non-null   object
#  24  job_code_seq3          1126 non-null   object
#  25  career_month           57946 non-null  int64
#  26  career_job_code        54557 non-null  object
#  27  certificate_contents   42235 non-null  object
#  28  hischool_type_seq      57946 non-null  int64
#  29  hischool_special_type  57946 non-null  object
#  30  hischool_nation        57946 non-null  object
#  31  hischool_gender        57946 non-null  object
#  32  hischool_location_seq  57946 non-null  int64
#  33  univ_type_seq1         57946 non-null  int64
#  34  univ_type_seq2         57946 non-null  int64
#  35  univ_transfer          57946 non-null  int64
#  36  univ_location          57946 non-null  int64
#  37  univ_major             12864 non-null  object
#  38  univ_sub_major         2641 non-null   object
#  39  univ_major_type        57946 non-null  int64
#  40  univ_score             57946 non-null  float64
#  41  language               5051 non-null   float64
#  42  exam_name              5051 non-null   float64
#  43  score                  5051 non-null   float64
# dtypes: float64(10), int64(17), object(17)
# memory usage: 19.9+ MB

# %%
#5번 지역 삭제

new_merged_total = merged_total[merged_total['address_seq1'] != 5.0]
new_merged_total
# Out:
#       resume_seq recruitment_seq  address_seq1  address_seq2  address_seq3  \
# 0         U05833          R03838           3.0           NaN           NaN
# 1         U06456          R02144           3.0           NaN           NaN
# 2         U07807          R01877           3.0           NaN           NaN
# 3         U04842          R02463           3.0           NaN           NaN
# 4         U08336          R00112           3.0           NaN           NaN
# ...          ...             ...           ...           ...           ...
# 57941     U02270          R03430           3.0           NaN           NaN
# 57942     U02640          R04987           3.0           1.0           NaN
# 57943     U08238          R01342           3.0           NaN           NaN
# 57944     U01296          R06363           3.0           NaN           NaN
# 57945     U05748          R03090           3.0           NaN           NaN
#
#        career_end  career_start    check_box_keyword  education  major_task  \
# 0               0             0  2110;2203;2204;2299          3           2
# 1               0             0       2204;2507;2707          3           2
# 2               0             0            2507;2707          3           2
# 3               0             0            2507;2707          4           2
# 4               0             0            2507;2707          3           8
# ...           ...           ...                  ...        ...         ...
# 57941           0             0            2507;2707          3           2
# 57942           0             0            2707;2507          3           2
# 57943           0             0  2201;2204;2205;2707          2           2
# 57944           0             0  2201;2204;2205;2707          3           2
# 57945           0             0            2102;2707          3           2
#
#        ...  univ_type_seq2 univ_transfer  univ_location  univ_major  \
# 0      ...               5             0              3         NaN
# 1      ...               5             0             10      국어국문학과
# 2      ...               5             0             15         NaN
# 3      ...               5             0              3         NaN
# 4      ...               5             0             17         NaN
# ...    ...             ...           ...            ...         ...
# 57941  ...              10             0              5    패션디자인과종합
# 57942  ...               5             0              3        조소학과
# 57943  ...               5             0             12         NaN
# 57944  ...               5             0             18      의상디자인학
# 57945  ...               5             0              3       금속공학과
#
#        univ_sub_major univ_major_type univ_score  language  exam_name  score
# 0                 NaN               3       60.0       NaN        NaN    NaN
# 1                 NaN               8       70.0       NaN        NaN    NaN
# 2                 NaN               4       80.0       NaN        NaN    NaN
# 3                 NaN               9       80.0       NaN        NaN    NaN
# 4                 NaN               9       70.0       NaN        NaN    NaN
# ...               ...             ...        ...       ...        ...    ...
# 57941             NaN               9        0.0       NaN        NaN    NaN
# 57942             NaN               9       70.0       NaN        NaN    NaN
# 57943             NaN               3       70.0       NaN        NaN    NaN
# 57944             NaN               9       80.0       NaN        NaN    NaN
# 57945             NaN              10       70.0       NaN        NaN    NaN
#
# [56471 rows x 44 columns]

# %% [markdown]
# 조건 2 적용해서 new_apply_train을 생성한다

# %%
#new_merged_total = drop_degree(merged_total)

# %%
#new_merged_total.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 44469 entries, 0 to 57945
# Data columns (total 44 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   resume_seq             44469 non-null  object
#  1   recruitment_seq        44469 non-null  object
#  2   address_seq1           44463 non-null  float64
#  3   address_seq2           568 non-null    float64
#  4   address_seq3           24 non-null     float64
#  5   career_end             44469 non-null  int64
#  6   career_start           44469 non-null  int64
#  7   check_box_keyword      44469 non-null  object
#  8   education              44469 non-null  int64
#  9   major_task             44469 non-null  int64
#  10  qualifications         44469 non-null  int64
#  11  text_keyword_x         4547 non-null   object
#  12  company_type_seq       15958 non-null  float64
#  13  supply_kind            15958 non-null  float64
#  14  employee               15958 non-null  float64
#  15  reg_date               44469 non-null  object
#  16  updated_date           44469 non-null  object
#  17  degree                 44469 non-null  int64
#  18  graduate_date          44469 non-null  int64
#  19  hope_salary            44469 non-null  int64
#  20  last_salary            44469 non-null  int64
#  21  text_keyword_y         43547 non-null  object
#  22  job_code_seq1          44469 non-null  object
#  23  job_code_seq2          2143 non-null   object
#  24  job_code_seq3          801 non-null    object
#  25  career_month           44469 non-null  int64
#  26  career_job_code        41835 non-null  object
#  27  certificate_contents   32480 non-null  object
#  28  hischool_type_seq      44469 non-null  int64
#  29  hischool_special_type  44469 non-null  object
#  30  hischool_nation        44469 non-null  object
#  31  hischool_gender        44469 non-null  object
#  32  hischool_location_seq  44469 non-null  int64
#  33  univ_type_seq1         44469 non-null  int64
#  34  univ_type_seq2         44469 non-null  int64
#  35  univ_transfer          44469 non-null  int64
#  36  univ_location          44469 non-null  int64
#  37  univ_major             9886 non-null   object
#  38  univ_sub_major         2075 non-null   object
#  39  univ_major_type        44469 non-null  int64
#  40  univ_score             44469 non-null  float64
#  41  language               3932 non-null   float64
#  42  exam_name              3932 non-null   float64
#  43  score                  3932 non-null   float64
# dtypes: float64(10), int64(17), object(17)
# memory usage: 15.3+ MB

# %%
new_apply_train = new_merged_total[['resume_seq', 'recruitment_seq']]
new_apply_train
# Out:
#       resume_seq recruitment_seq
# 0         U05833          R03838
# 1         U06456          R02144
# 2         U07807          R01877
# 3         U04842          R02463
# 4         U08336          R00112
# ...          ...             ...
# 57938     U00788          R04337
# 57941     U02270          R03430
# 57942     U02640          R04987
# 57944     U01296          R06363
# 57945     U05748          R03090
#
# [44469 rows x 2 columns]

# %%
#before
apply_train.shape
# Out:
# (57946, 2)

# %%
apply_train['resume_seq'].nunique(), apply_train['recruitment_seq'].nunique()
# Out:
# (8482, 6695)

# %%
apply_train['resume_seq'].value_counts()
# Out:
# U06543    77
# U07490    69
# U06166    65
# U06206    63
# U06125    63
#           ..
# U05406     2
# U00727     2
# U04660     2
# U08300     2
# U05310     2
# Name: resume_seq, Length: 8482, dtype: int64

# %%
#after
new_apply_train.shape
# Out:
# (44469, 2)

# %%
new_apply_train['resume_seq'].nunique(), new_apply_train['recruitment_seq'].nunique() # 5번 지역만! 쓴 사람은 1명밖에 없네
# Out:
# (8318, 6203)

# %%
#missing_resume

missing_resume = list(set(apply_train['resume_seq']) - set(new_apply_train['resume_seq']))
len(missing_resume)
# Out:
# 164

# %%
#just_one_resume
unique_resume_seq = new_apply_train['resume_seq'].value_counts()
just_one_resume = unique_resume_seq[unique_resume_seq == 1]
just_one_resume = just_one_resume.index.tolist()

# %%
#resume_seq가 전부 다 날라간 애들이 적어도 두개는 new_apply_train에 포함되도록 랜덤하게 추출하여 add
new_rows = pd.DataFrame()

for resume in missing_resume:
    temp = apply_train[apply_train['resume_seq'] == resume]
    random_rows = temp.sample(n=2, random_state=args.random_state)
    new_rows = pd.concat([new_rows, random_rows], ignore_index=True)

# new_apply_train에 새로운 행 추가
new_apply_train = pd.concat([new_apply_train, new_rows], ignore_index=True)

# %%
new_apply_train['resume_seq'].nunique(), new_apply_train['recruitment_seq'].nunique()
# Out:
# (8482, 6265)

# %%
for resume in tqdm(just_one_resume):
    temp = apply_train[apply_train['resume_seq'] == resume]

    # new_apply_train에서 resume_seq가 resume인 항목들만 필터링
    new_apply_subset = new_apply_train[new_apply_train['resume_seq'] == resume]

    # temp에서 랜덤으로 1개의 행을 추출하고, new_apply_subset에 없는 행을 찾을 때까지 반복
    while True:
        random_row = temp.sample(n=1, random_state=args.random_state)

        # new_apply_subset에 random_row가 존재하지 않는 경우에만 추가하고 반복 중단
        if not random_row.index.isin(new_apply_subset.index).any():
            new_apply_train = pd.concat([new_apply_train, random_row])
            break
# Out:
#   0%|          | 0/858 [00:00<?, ?it/s]

# %%
#모든 resume가 다  채워졌나?

new_apply_train['resume_seq'].nunique(), new_apply_train['recruitment_seq'].nunique()
# Out:
# (8482, 6369)

# %%
#missing_recruitment

missing_recruitment = list(set(apply_train['recruitment_seq']) - set(new_apply_train['recruitment_seq']))
len(missing_recruitment)
# Out:
# 326

# %%
#new_apply_train에 최소 한개의 recruitment는 들어가도록 추가(train/test)

for recruitment in missing_recruitment:
    temp = apply_train[apply_train['recruitment_seq'] == recruitment]
    if not temp.empty:  # temp가 비어 있지 않은 경우에만 실행
        random_row = temp.sample(n=1, random_state=args.random_state)
        new_apply_train = pd.concat([new_apply_train, random_row], ignore_index=True)

# %%
#모든 recruitment가 다  채워졌나?

new_apply_train['resume_seq'].nunique(), new_apply_train['recruitment_seq'].nunique()
# Out:
# (8482, 6695)

# %%
#결과 비교
print(f"before shape : {apply_train.shape}, after shape : {new_apply_train.shape}")
# Out:
# before shape : (57946, 2), after shape : (45981, 2)

# %% [markdown]
# # Apply_Matrix 생성

# %%
#학습, 검증 분리
train, test = [], []
new_apply_train_groupby = new_apply_train.groupby('resume_seq')['recruitment_seq'].apply(list)
for uid, iids in zip(new_apply_train_groupby.index.tolist(), new_apply_train_groupby.values.tolist()):
    for iid in iids[:-1]:
        train.append([uid,iid])
    test.append([uid, iids[-1]])

# %%
train = pd.DataFrame(train, columns=['resume_seq', 'recruitment_seq'])
test = pd.DataFrame(test, columns=['resume_seq', 'recruitment_seq'])

# %%
train.shape, test.shape
# Out:
# ((37499, 2), (8482, 2))

# %%
pred = new_apply_train.copy()

# %%
from sklearn.metrics.pairwise import cosine_similarity

# %%
train_user_item_matrix = train.groupby(['resume_seq', 'recruitment_seq']).size().unstack(fill_value=0)
pred_user_item_matrix  = pred.groupby(['resume_seq', 'recruitment_seq']).size().unstack(fill_value=0)

# %%
train_user_similarity  = cosine_similarity(train_user_item_matrix) # 이력서 간의 유사성 계산
pred_user_similarity  = cosine_similarity(pred_user_item_matrix) # apply 이력서 간의 유사성 계산

# %%
train_item_similarity = cosine_similarity(train_user_item_matrix.T) # 공고 간의 유사성 계산
pred_item_similarity = cosine_similarity(pred_user_item_matrix.T) # apply 공고 간의 유사성 계산

# %%
train_user_predicted_scores = train_user_similarity.dot(train_user_item_matrix)
# 이력서간의 유사도 X 이력서-공고 매트릭스 행렬곱
train_item_predicted_scores = train_user_item_matrix.dot(train_item_similarity)
# 이력서-공고 매트릭스 X 공고간의 유사도 행렬곱

pred_user_predicted_scores = pred_user_similarity.dot(pred_user_item_matrix)
pred_item_predicted_scores = pred_user_item_matrix.dot(pred_item_similarity)

# %% [markdown]
# # train/test 결과 도출

# %%
alpha = 0.5
beta = 0.5
train_recommendations = []

for idx, user in tqdm(enumerate(train_user_item_matrix.index)):
    applied_jobs = set(train_user_item_matrix.loc[user][train_user_item_matrix.loc[user] == 1].index)

    # 해당 사용자의 추천 점수 (높은 점수부터 정렬)
    sorted_job_indices = (train_item_predicted_scores.loc[user].values * alpha + train_user_predicted_scores[idx] * beta).argsort()[::-1]

    # 이미 지원하지 않은 공고를 선택
    recommended_jobs = [job for job in train_user_item_matrix.columns[sorted_job_indices] if job not in applied_jobs][:5]

    for job in recommended_jobs:
        train_recommendations.append([user, job])
# Out:
# 0it [00:00, ?it/s]

# %% [markdown]
# # Recall

# %%
def recall5(answer_df, submission_df):

    primary_col = answer_df.columns[0]
    secondary_col = answer_df.columns[1]

    # submission의 예측이 각각 5개인지 확인
    prediction_counts = submission_df.groupby(primary_col).size()
    if not all(prediction_counts == 5):
        raise ValueError(f"Each {primary_col} should have exactly 5 {secondary_col} predictions.")


    # submission의 예측된 값들에 null값이 있는지 확인
    if submission_df[secondary_col].isnull().any():
        raise ValueError(f"Predicted {secondary_col} contains NULL values.")

    # 예측값에 중복이 있는지 확인
    duplicated_preds = submission_df.groupby(primary_col).apply(lambda x: x[secondary_col].duplicated().any())
    if duplicated_preds.any():
        raise ValueError(f"Predicted {secondary_col} contains duplicates for some {primary_col}.")


    # Filter the submission dataframe based on the primary_col present in the answer dataframe
    # primary_col 즉 resume_seq가 양측에 있는지 확인 후 남김
    submission_df = submission_df[submission_df[primary_col].isin(answer_df[primary_col])]

    # For each primary_col, get the top 5 predicted secondary_col values
    #
    top_5_preds = submission_df.groupby(primary_col).apply(lambda x: x[secondary_col].head().tolist()).to_dict()

    # Convert the answer_df to a dictionary for easier lookup
    true_dict = answer_df.groupby(primary_col).apply(lambda x: x[secondary_col].tolist()).to_dict()


    individual_recalls = []
    for key, val in true_dict.items():
        if key in top_5_preds:
            correct_matches = len(set(true_dict[key]) & set(top_5_preds[key]))
            individual_recall = correct_matches / min(len(val), 5) # 공정한 평가를 가능하게 위하여 분모(k)를 'min(len(val), 5)' 로 설정함
            individual_recalls.append(individual_recall)


    recall = np.mean(individual_recalls)
    return recall

# %%
train_recommendations = pd.DataFrame(train_recommendations, columns=['resume_seq', 'recruitment_seq'])

# %%
recall5(test,train_recommendations)
# Out:
# 0.1085828813958972

# %% [markdown]
# # 최적의 Alpha, Beta 값 탐색

# %%
def calculate_recommendations(alpha, train_user_item_matrix, train_item_predicted_scores, train_user_predicted_scores):
    train_recommendations = []

    for idx, user in enumerate(train_user_item_matrix.index):
        applied_jobs = set(train_user_item_matrix.loc[user][train_user_item_matrix.loc[user] == 1].index)
        sorted_job_indices = (train_item_predicted_scores.loc[user].values * alpha + train_user_predicted_scores[idx] * (1 - alpha)).argsort()[::-1]
        recommended_jobs = [job for job in train_user_item_matrix.columns[sorted_job_indices] if job not in applied_jobs][:5]

        for job in recommended_jobs:
            train_recommendations.append([user, job])

    return pd.DataFrame(train_recommendations, columns=['resume_seq', 'recruitment_seq'])

# %%
random_state = args.random_state
random.seed(random_state)

# 초기화
n_iter = 0
max_iter = 10
pbar = tqdm(total=max_iter)
best_score = 0
best_alpha = 0.0
best_beta = 0.0

while n_iter < max_iter:
    alpha = round(random.uniform(0, 1), 3)
    train_recommendations = calculate_recommendations(alpha, train_user_item_matrix, train_item_predicted_scores, train_user_predicted_scores)
    score = recall5(test, train_recommendations)

    if score > best_score:
        best_score = score
        best_alpha = alpha
        best_beta = 1 - alpha

    n_iter += 1
    pbar.update(1)

pbar.close()
print(f"Best score: {best_score}, Best alpha: {best_alpha}, Best beta: {best_beta}")
# Out:
#   0%|          | 0/10 [00:00<?, ?it/s]
# Best score: 0.1102334355104928, Best alpha: 0.275, Best beta: 0.725

# %% [markdown]
# # Submission

# %%
random_state = args.random_state
random.seed(random_state)

top_recommendations = []

for idx, user in tqdm(enumerate(pred_user_item_matrix.index)):
    applied_jobs = set(pred_user_item_matrix.loc[user][pred_user_item_matrix.loc[user] == 1].index)

    # 해당 사용자의 추천 점수 (높은 점수부터 정렬)
    sorted_job_indices = (pred_item_predicted_scores.loc[user].values * best_alpha + pred_user_predicted_scores[idx] * best_beta).argsort()[::-1]

    # 이미 지원하지 않은 공고를 선택
    recommended_jobs = [job for job in pred_user_item_matrix.columns[sorted_job_indices] if job not in applied_jobs][:5]


    for job in recommended_jobs:
        top_recommendations.append([user, job])
# Out:
# 0it [00:00, ?it/s]

# %%
pred_recommendations = pd.DataFrame(top_recommendations, columns=['resume_seq', 'recruitment_seq'])

# %%
now = datetime.now() + timedelta(hours=9)
formatted_time = now.strftime("%Y%m%d_%H%M")
formatted_time
# Out:
# '20231113_0600'

# %%
방지턱
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-126-62caed13d533> in <cell line: 1>()
# ----> 1 방지턱
#
# NameError: name '방지턱' is not defined

# %%
pred_recommendations.to_csv('/content/data/MyDrive/dev/deep learning/국민대 ai 경진대회 데이콘/result/submission_20231113-3.csv', index=False)
